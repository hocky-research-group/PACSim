# %%
# %run benchmark.py
# Out:
# Time per time step: 0.054060290600000005 s / step (platform: Reference, potentials: algebraic, use_log: False, number_steps: 10)
# Time per time step: 2.0690357743 s / step (platform: Reference, potentials: tabulated, use_log: False, number_steps: 10)
# Time per time step: 0.0056205578 s / step (platform: CPU, potentials: algebraic, use_log: False, number_steps: 100)
# Time per time step: 0.25615144644 s / step (platform: CPU, potentials: tabulated, use_log: False, number_steps: 100)
# There is no registered Platform called "OpenCL"
# There is no registered Platform called "OpenCL"
# Time per time step: 6.7542457e-05 s / step (platform: CUDA, potentials: algebraic, use_log: False, number_steps: 1000)
# Time per time step: 0.000149986748 s / step (platform: CUDA, potentials: tabulated, use_log: False, number_steps: 1000)
#
# Time per time step: 0.054431941000000005 s / step (platform: Reference, potentials: algebraic, use_log: True, number_steps: 10)
# ...
