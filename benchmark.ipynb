# %%
# %run benchmark.py --all
# Out:
# Time per time step: 0.0254519459 s / step (platform: Reference, potentials: algebraic, use_log: False, number_steps: 10)
# 544.8339222910043
# 742.4729100406043
# -635.2268230347394
# Time per time step: 0.6016230792 s / step (platform: Reference, potentials: tabulated, use_log: False, number_steps: 10)
# Time per time step: 0.00111091275 s / step (platform: CPU, potentials: algebraic, use_log: False, number_steps: 1000)
# 544.8339222910043
# 742.4729100406043
# -635.2268230347394
# Time per time step: 0.010483902083 s / step (platform: CPU, potentials: tabulated, use_log: False, number_steps: 1000)
# Time per time step: 0.00026501066700000003 s / step (platform: OpenCL, potentials: algebraic, use_log: False, number_steps: 1000)
# 544.8339222910043
# 742.4729100406043
# -635.2268230347394
# Time per time step: 1.2283792e-05 s / step (platform: OpenCL, potentials: tabulated, use_log: False, number_steps: 1000)
# There is no registered Platform called "CUDA"
# ...

# %%
# %run benchmark_hoomd.py --all
# Out:
# Time per time step: 0.000905111833 s / step (device: CPU, number_steps: 1000, shift: False)
# Time per time step: 0.0009145308750000001 s / step (device: CPU, number_steps: 1000, shift: True)
# **ERROR**: GPU execution requested, but this hoomd was built without CUDA support
# Error initializing execution configuration
# **ERROR**: GPU execution requested, but this hoomd was built without CUDA support
# Error initializing execution configuration
